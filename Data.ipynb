-- %% [markdown]
-- # [CompraArtículosLínea]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [CompraArtículosLínea]    Script Date: 9/12/2024 21:19:10 ******/
CREATE DATABASE [CompraArtículosLínea]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'CompraArtículosLínea', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\CompraArtículosLínea.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'CompraArtículosLínea_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\CompraArtículosLínea_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [CompraArtículosLínea] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [CompraArtículosLínea].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [CompraArtículosLínea] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET ARITHABORT OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [CompraArtículosLínea] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [CompraArtículosLínea] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET  ENABLE_BROKER 
GO
ALTER DATABASE [CompraArtículosLínea] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [CompraArtículosLínea] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET RECOVERY FULL 
GO
ALTER DATABASE [CompraArtículosLínea] SET  MULTI_USER 
GO
ALTER DATABASE [CompraArtículosLínea] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [CompraArtículosLínea] SET DB_CHAINING OFF 
GO
ALTER DATABASE [CompraArtículosLínea] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [CompraArtículosLínea] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [CompraArtículosLínea] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [CompraArtículosLínea] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'CompraArtículosLínea', N'ON'
GO
ALTER DATABASE [CompraArtículosLínea] SET QUERY_STORE = ON
GO
ALTER DATABASE [CompraArtículosLínea] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[DetallePedido]

-- %%
USE [CompraArtículosLínea]
GO

-- %%
/****** Object:  Table [dbo].[DetallePedido]    Script Date: 9/12/2024 21:19:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetallePedido](
	[DetallePedidoId] [int] IDENTITY(1,1) NOT NULL,
	[PedidoId] [int] NOT NULL,
	[ProductoId] [int] NOT NULL,
	[Cantidad] [int] NOT NULL,
	[Subtotal] [decimal](18, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[DetallePedidoId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pedido]

-- %%
/****** Object:  Table [dbo].[Pedido]    Script Date: 9/12/2024 21:19:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pedido](
	[PedidoId] [int] IDENTITY(1,1) NOT NULL,
	[UsuarioId] [int] NOT NULL,
	[PrecioTotal] [decimal](18, 2) NOT NULL,
	[Estado] [nvarchar](50) NOT NULL,
	[Fecha] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[PedidoId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Producto]

-- %%
/****** Object:  Table [dbo].[Producto]    Script Date: 9/12/2024 21:19:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Producto](
	[ProductoId] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[Descripcion] [nvarchar](500) NULL,
	[Precio] [decimal](18, 2) NOT NULL,
	[Categoria] [nvarchar](100) NOT NULL,
	[Stock] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ProductoId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 9/12/2024 21:19:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[UsuarioId] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[NombreUsuario] [nvarchar](50) NOT NULL,
	[Contrasena] [nvarchar](100) NOT NULL,
	[Email] [nvarchar](100) NULL,
	[Direccion] [nvarchar](200) NULL,
	[Telefono] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[UsuarioId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DetallePedido]

-- %%
SET IDENTITY_INSERT [dbo].[DetallePedido] ON 
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (1, 1, 1, 1, CAST(120.99 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (2, 1, 2, 1, CAST(120.00 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (3, 2, 3, 2, CAST(120.00 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (4, 2, 4, 1, CAST(25.00 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (5, 3, 1, 1, CAST(12099.00 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (6, 3, 3, 1, CAST(6000.00 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (7, 3, 7, 1, CAST(8500.00 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (8, 4, 6, 1, CAST(14000.00 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (9, 4, 4, 1, CAST(11000.00 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (10, 4, 7, 1, CAST(8500.00 AS Decimal(18, 2)))
INSERT [dbo].[DetallePedido] ([DetallePedidoId], [PedidoId], [ProductoId], [Cantidad], [Subtotal]) VALUES (11, 4, 12, 1, CAST(15000.00 AS Decimal(18, 2)))
SET IDENTITY_INSERT [dbo].[DetallePedido] OFF
GO

-- %% [markdown]
-- # [dbo].[Pedido]

-- %%
SET IDENTITY_INSERT [dbo].[Pedido] ON 
INSERT [dbo].[Pedido] ([PedidoId], [UsuarioId], [PrecioTotal], [Estado], [Fecha]) VALUES (1, 1, CAST(240.99 AS Decimal(18, 2)), N'Pendiente', CAST(N'2024-11-27T22:01:31.543' AS DateTime))
INSERT [dbo].[Pedido] ([PedidoId], [UsuarioId], [PrecioTotal], [Estado], [Fecha]) VALUES (2, 2, CAST(145.00 AS Decimal(18, 2)), N'Completado', CAST(N'2024-11-27T22:01:31.543' AS DateTime))
INSERT [dbo].[Pedido] ([PedidoId], [UsuarioId], [PrecioTotal], [Estado], [Fecha]) VALUES (3, 3, CAST(26599.00 AS Decimal(18, 2)), N'Pagado', CAST(N'2024-12-09T00:00:02.597' AS DateTime))
INSERT [dbo].[Pedido] ([PedidoId], [UsuarioId], [PrecioTotal], [Estado], [Fecha]) VALUES (4, 3, CAST(48500.00 AS Decimal(18, 2)), N'Pagado', CAST(N'2024-12-09T17:51:37.173' AS DateTime))
SET IDENTITY_INSERT [dbo].[Pedido] OFF
GO

-- %% [markdown]
-- # [dbo].[Producto]

-- %%
SET IDENTITY_INSERT [dbo].[Producto] ON 
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (1, N'Nike Air Max', N'Tenis deportivos con tecnología de amortiguación Air Max.', CAST(12099.00 AS Decimal(18, 2)), N'Deportivos', 50)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (2, N'Adidas Ultraboost', N'Tenis para correr con retorno de energía Boost.', CAST(18050.00 AS Decimal(18, 2)), N'Deportivos', 30)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (3, N'Converse Chuck Taylor', N'Tenis clásicos de lona con diseño icónico.', CAST(6000.00 AS Decimal(18, 2)), N'Casual', 100)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (4, N'Puma RS-X', N'Tenis modernos con diseño retro-futurista.', CAST(11000.00 AS Decimal(18, 2)), N'Deportivos', 40)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (5, N'Nike Dunk Low', N'Tenis casuales con diseño retro de los 80.', CAST(10000.00 AS Decimal(18, 2)), N'Casual', 25)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (6, N'Adidas NMD R1', N'Tenis urbanos con estilo minimalista.', CAST(14000.00 AS Decimal(18, 2)), N'Casual', 35)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (7, N'Converse Run Star Hike', N'Tenis con plataforma y diseño robusto.', CAST(8500.00 AS Decimal(18, 2)), N'Casual', 20)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (8, N'Puma Suede Classic', N'Tenis clásicos de gamuza con estilo casual.', CAST(7500.00 AS Decimal(18, 2)), N'Casual', 50)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (9, N'Gorra Nike', N'Gorra deportiva unisex', CAST(5000.00 AS Decimal(18, 2)), N'Accesorios', 20)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (10, N'Suéter Adidas', N'Suéter casual con capucha', CAST(12000.00 AS Decimal(18, 2)), N'Ropa', 15)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (11, N'Jacket Puma', N'Jacket impermeable para exteriores', CAST(18000.00 AS Decimal(18, 2)), N'Ropa', 10)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (12, N'Sudadera Reebok', N'Sudadera cómoda para entrenamiento', CAST(15000.00 AS Decimal(18, 2)), N'Ropa', 25)
INSERT [dbo].[Producto] ([ProductoId], [Nombre], [Descripcion], [Precio], [Categoria], [Stock]) VALUES (13, N'Short Deportivo', N'Short ligero para ejercicio', CAST(7000.00 AS Decimal(18, 2)), N'Ropa', 30)
SET IDENTITY_INSERT [dbo].[Producto] OFF
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
SET IDENTITY_INSERT [dbo].[Usuario] ON 
INSERT [dbo].[Usuario] ([UsuarioId], [Nombre], [NombreUsuario], [Contrasena], [Email], [Direccion], [Telefono]) VALUES (1, N'Juan Pérez', N'juanp', N'hashed_password_1', N'juanp@gmail.com', N'Av. Central 123', N'1234567890')
INSERT [dbo].[Usuario] ([UsuarioId], [Nombre], [NombreUsuario], [Contrasena], [Email], [Direccion], [Telefono]) VALUES (2, N'María López', N'marial', N'hashed_password_2', N'marial@gmail.com', N'Calle 45 Norte', N'0987654321')
INSERT [dbo].[Usuario] ([UsuarioId], [Nombre], [NombreUsuario], [Contrasena], [Email], [Direccion], [Telefono]) VALUES (3, N'José Leonardo Ryes Hernández', N'lreyes', N'$2a$11$2Ad/XPxCBcQL2vT1PM4RleXzYhyCOTObdCE9Y4o1iGLwy9BixaPBu', N'lvdanaela@gmail.com', N'Curridabat, costado norte del estadio Lito Monge de Curridabat', N'89443915')
INSERT [dbo].[Usuario] ([UsuarioId], [Nombre], [NombreUsuario], [Contrasena], [Email], [Direccion], [Telefono]) VALUES (4, N'José Leonardo Ryes Hernández', N'lreyesH', N'$2a$11$BgRJAZZioRxPjIGZmvwc.eqJrE3ZWY9.SfzG6lfsld.OpEGkl9me2', N'lvdanaela@gmail.com', N'Curridabat, costado norte del estadio Lito Monge de Curridabat', N'89443915')
INSERT [dbo].[Usuario] ([UsuarioId], [Nombre], [NombreUsuario], [Contrasena], [Email], [Direccion], [Telefono]) VALUES (1003, N'Veronica Villanueva Baltodano', N'vvilla', N'$2a$11$575.E6W3gdfHHAFAlyRvjOk/2cFPnunLD6fa/umBiIfxfqmwP5LSa', N'lvdanaela@hotmail.com', N'Costado norte del estadio de curridabat', N'83291438')
INSERT [dbo].[Usuario] ([UsuarioId], [Nombre], [NombreUsuario], [Contrasena], [Email], [Direccion], [Telefono]) VALUES (1004, N'Carlos Luis Villanueva uesada', N'reyesh', N'$2a$11$s.Eq4kttBhGW0Yg0smyJO.rgrU5VEStARDzIif9.c5e2oxlRE.oze', N'lvdana@gmail.com', N'Costado norte del estadio de curridabat', N'89443915')
SET IDENTITY_INSERT [dbo].[Usuario] OFF
GO

-- %% [markdown]
-- # [UQ__Usuario__6B0F5AE0EABBA6FA]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Usuario__6B0F5AE0EABBA6FA]    Script Date: 9/12/2024 21:19:10 ******/
ALTER TABLE [dbo].[Usuario] ADD UNIQUE NONCLUSTERED 
(
	[NombreUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__DetallePe__Pedid__44FF419A]

-- %%
ALTER TABLE [dbo].[DetallePedido]  WITH CHECK ADD FOREIGN KEY([PedidoId])
REFERENCES [dbo].[Pedido] ([PedidoId])
GO

-- %% [markdown]
-- # [FK__DetallePe__Produ__45F365D3]

-- %%
ALTER TABLE [dbo].[DetallePedido]  WITH CHECK ADD FOREIGN KEY([ProductoId])
REFERENCES [dbo].[Producto] ([ProductoId])
GO

-- %% [markdown]
-- # [FK__Pedido__UsuarioI__403A8C7D]

-- %%
ALTER TABLE [dbo].[Pedido]  WITH CHECK ADD FOREIGN KEY([UsuarioId])
REFERENCES [dbo].[Usuario] ([UsuarioId])
GO

-- %% [markdown]
-- # [CK__DetallePe__Canti__4316F928]

-- %%
ALTER TABLE [dbo].[DetallePedido]  WITH CHECK ADD CHECK  (([Cantidad]>=(1)))
GO

-- %% [markdown]
-- # [CK__DetallePe__Subto__440B1D61]

-- %%
ALTER TABLE [dbo].[DetallePedido]  WITH CHECK ADD CHECK  (([Subtotal]>(0)))
GO

-- %% [markdown]
-- # [CK__Pedido__PrecioTo__3F466844]

-- %%
ALTER TABLE [dbo].[Pedido]  WITH CHECK ADD CHECK  (([PrecioTotal]>(0)))
GO

-- %% [markdown]
-- # [CK__Producto__Precio__37A5467C]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD CHECK  (([Precio]>(0)))
GO

-- %% [markdown]
-- # [CK__Producto__Stock__38996AB5]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD CHECK  (([Stock]>=(0)))
GO

-- %% [markdown]
-- # [CK__Usuario__Email__3C69FB99]

-- %%
ALTER TABLE [dbo].[Usuario]  WITH CHECK ADD CHECK  (([Email] like '%@%.%'))
GO

-- %% [markdown]
-- # [CompraArtículosLínea]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [CompraArtículosLínea] SET  READ_WRITE 
GO
